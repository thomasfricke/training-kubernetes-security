# %% [markdown]
# **This notebook is covered by the following [license](License.ipynb)  This note must not be removed**

# %% [markdown]
# ## Cluster Overview

# %% [markdown]
# Outside the notebook type `minikube dashboard`

# %%
kubectl get all -A
# Out:
# NAMESPACE              NAME                                            READY   STATUS    RESTARTS   AGE
# default                pod/my-nginx-5b56ccd65f-8krqn                   1/1     Running   0          48m
# default                pod/my-nginx-5b56ccd65f-s8qwn                   1/1     Running   0          48m
# kube-system            pod/coredns-74ff55c5b-bx9lj                     1/1     Running   0          130m
# kube-system            pod/etcd-minikube                               1/1     Running   0          130m
# kube-system            pod/kube-apiserver-minikube                     1/1     Running   0          130m
# kube-system            pod/kube-controller-manager-minikube            1/1     Running   0          130m
# kube-system            pod/kube-proxy-2rf67                            1/1     Running   0          130m
# kube-system            pod/kube-scheduler-minikube                     1/1     Running   0          130m
# kube-system            pod/storage-provisioner                         1/1     Running   0          130m
# kubernetes-dashboard   pod/dashboard-metrics-scraper-c95fcf479-zchqb   1/1     Running   0          119s
# kubernetes-dashboard   pod/kubernetes-dashboard-6cff4c7c4f-68nvz       1/1     Running   0          118s
#
# NAMESPACE              NAME                                TYPE           CLUSTER-IP      EXTERNAL-IP   PORT(S)                  AGE
# default                service/kubernetes                  ClusterIP      10.96.0.1       <none>        443/TCP                  130m
# default                service/my-nginx                    LoadBalancer   10.97.45.87     10.97.45.87   80:31446/TCP             48m
# kube-system            service/kube-dns                    ClusterIP      10.96.0.10      <none>        53/UDP,53/TCP,9153/TCP   130m
# kubernetes-dashboard   service/dashboard-metrics-scraper   ClusterIP      10.108.39.30    <none>        8000/TCP                 119s
# kubernetes-dashboard   service/kubernetes-dashboard        ClusterIP      10.111.143.65   <none>        80/TCP                   119s
#
# NAMESPACE     NAME                        DESIRED   CURRENT   READY   UP-TO-DATE   AVAILABLE   NODE SELECTOR            AGE
# kube-system   daemonset.apps/kube-proxy   1         1         1       1            1           kubernetes.io/os=linux   130m
#
# NAMESPACE              NAME                                        READY   UP-TO-DATE   AVAILABLE   AGE
# default                deployment.apps/my-nginx                    2/2     2            2           48m
# kube-system            deployment.apps/coredns                     1/1     1            1           130m
# kubernetes-dashboard   deployment.apps/dashboard-metrics-scraper   1/1     1            1           2m
# kubernetes-dashboard   deployment.apps/kubernetes-dashboard        1/1     1            1           2m
#
# NAMESPACE              NAME                                                  DESIRED   CURRENT   READY   AGE
# default                replicaset.apps/my-nginx-5b56ccd65f                   2         2         2       48m
# kube-system            replicaset.apps/coredns-74ff55c5b                     1         1         1       130m
# kubernetes-dashboard   replicaset.apps/dashboard-metrics-scraper-c95fcf479   1         1         1       2m
# kubernetes-dashboard   replicaset.apps/kubernetes-dashboard-6cff4c7c4f       1         1         1       2m

# %%
kubectl get events -n default
# Out:
# LAST SEEN   TYPE     REASON              OBJECT                           MESSAGE
# 48m         Normal   Scheduled           pod/my-nginx-5b56ccd65f-8krqn    Successfully assigned default/my-nginx-5b56ccd65f-8krqn to minikube
# 48m         Normal   Pulling             pod/my-nginx-5b56ccd65f-8krqn    Pulling image "nginx"
# 48m         Normal   Pulled              pod/my-nginx-5b56ccd65f-8krqn    Successfully pulled image "nginx" in 11.260302375s
# 48m         Normal   Created             pod/my-nginx-5b56ccd65f-8krqn    Created container my-nginx
# 48m         Normal   Started             pod/my-nginx-5b56ccd65f-8krqn    Started container my-nginx
# 48m         Normal   Scheduled           pod/my-nginx-5b56ccd65f-s8qwn    Successfully assigned default/my-nginx-5b56ccd65f-s8qwn to minikube
# 48m         Normal   Pulling             pod/my-nginx-5b56ccd65f-s8qwn    Pulling image "nginx"
# 48m         Normal   Pulled              pod/my-nginx-5b56ccd65f-s8qwn    Successfully pulled image "nginx" in 12.645687297s
# 48m         Normal   Created             pod/my-nginx-5b56ccd65f-s8qwn    Created container my-nginx
# 48m         Normal   Started             pod/my-nginx-5b56ccd65f-s8qwn    Started container my-nginx
# 48m         Normal   SuccessfulCreate    replicaset/my-nginx-5b56ccd65f   Created pod: my-nginx-5b56ccd65f-s8qwn
# 48m         Normal   SuccessfulCreate    replicaset/my-nginx-5b56ccd65f   Created pod: my-nginx-5b56ccd65f-8krqn
# 48m         Normal   ScalingReplicaSet   deployment/my-nginx              Scaled up replica set my-nginx-5b56ccd65f to 2
# 40m         Normal   Type                service/my-nginx                 ClusterIP -> LoadBalancer

# %%
kubectl describe pod my-nginx
# Out:
# Name:         my-nginx-5b56ccd65f-8krqn
# Namespace:    default
# Priority:     0
# Node:         minikube/192.168.49.2
# Start Time:   Tue, 26 Jan 2021 09:39:06 +0000
# Labels:       pod-template-hash=5b56ccd65f
#               run=my-nginx
# Annotations:  <none>
# Status:       Running
# IP:           172.17.0.4
# IPs:
#   IP:           172.17.0.4
# Controlled By:  ReplicaSet/my-nginx-5b56ccd65f
# Containers:
#   my-nginx:
#     Container ID:   docker://3f53be8b44dfe15ab9e05ac9a2cfed41dbdb616b55b8db935701babd2110fb39
#     Image:          nginx
#     Image ID:       docker-pullable://nginx@sha256:10b8cc432d56da8b61b070f4c7d2543a9ed17c2b23010b43af434fd40e2ca4aa
#     Port:           80/TCP
#     Host Port:      0/TCP
#     State:          Running
#       Started:      Tue, 26 Jan 2021 09:39:19 +0000
#     Ready:          True
#     Restart Count:  0
#     Environment:    <none>
#     Mounts:
#       /var/run/secrets/kubernetes.io/serviceaccount from default-token-6582g (ro)
# Conditions:
#   Type              Status
#   Initialized       True
#   Ready             True
#   ContainersReady   True
#   PodScheduled      True
# Volumes:
#   default-token-6582g:
#     Type:        Secret (a volume populated by a Secret)
#     SecretName:  default-token-6582g
#     Optional:    false
# QoS Class:       BestEffort
# Node-Selectors:  <none>
# Tolerations:     node.kubernetes.io/not-ready:NoExecute op=Exists for 300s
#                  node.kubernetes.io/unreachable:NoExecute op=Exists for 300s
# Events:
#   Type    Reason     Age   From               Message
#   ----    ------     ----  ----               -------
#   Normal  Scheduled  49m   default-scheduler  Successfully assigned default/my-nginx-5b56ccd65f-8krqn to minikube
#   Normal  Pulling    49m   kubelet            Pulling image "nginx"
#   Normal  Pulled     49m   kubelet            Successfully pulled image "nginx" in 11.260302375s
#   Normal  Created    49m   kubelet            Created container my-nginx
#   Normal  Started    49m   kubelet            Started container my-nginx
#
# Name:         my-nginx-5b56ccd65f-s8qwn
# Namespace:    default
# Priority:     0
# Node:         minikube/192.168.49.2
# Start Time:   Tue, 26 Jan 2021 09:39:06 +0000
# Labels:       pod-template-hash=5b56ccd65f
#               run=my-nginx
# Annotations:  <none>
# Status:       Running
# IP:           172.17.0.3
# IPs:
#   IP:           172.17.0.3
# Controlled By:  ReplicaSet/my-nginx-5b56ccd65f
# Containers:
#   my-nginx:
#     Container ID:   docker://5da141e6ccb8b419d9eb18f89cc5f7656329f819e17c9d6fcbcc2edb0dc530f4
#     Image:          nginx
#     Image ID:       docker-pullable://nginx@sha256:10b8cc432d56da8b61b070f4c7d2543a9ed17c2b23010b43af434fd40e2ca4aa
#     Port:           80/TCP
#     Host Port:      0/TCP
#     State:          Running
#       Started:      Tue, 26 Jan 2021 09:39:21 +0000
#     Ready:          True
#     Restart Count:  0
#     Environment:    <none>
#     Mounts:
#       /var/run/secrets/kubernetes.io/serviceaccount from default-token-6582g (ro)
# Conditions:
#   Type              Status
#   Initialized       True
#   Ready             True
#   ContainersReady   True
#   PodScheduled      True
# Volumes:
#   default-token-6582g:
#     Type:        Secret (a volume populated by a Secret)
#     SecretName:  default-token-6582g
#     Optional:    false
# QoS Class:       BestEffort
# Node-Selectors:  <none>
# Tolerations:     node.kubernetes.io/not-ready:NoExecute op=Exists for 300s
#                  node.kubernetes.io/unreachable:NoExecute op=Exists for 300s
# Events:
#   Type    Reason     Age   From               Message
#   ----    ------     ----  ----               -------
#   Normal  Scheduled  49m   default-scheduler  Successfully assigned default/my-nginx-5b56ccd65f-s8qwn to minikube
#   Normal  Pulling    49m   kubelet            Pulling image "nginx"
#   Normal  Pulled     49m   kubelet            Successfully pulled image "nginx" in 12.645687297s
#   Normal  Created    49m   kubelet            Created container my-nginx
#   Normal  Started    49m   kubelet            Started container my-nginx

# %%
kubectl describe pods
# Out:
# Name:         my-nginx-5b56ccd65f-8krqn
# Namespace:    default
# Priority:     0
# Node:         minikube/192.168.49.2
# Start Time:   Tue, 26 Jan 2021 09:39:06 +0000
# Labels:       pod-template-hash=5b56ccd65f
#               run=my-nginx
# Annotations:  <none>
# Status:       Running
# IP:           172.17.0.4
# IPs:
#   IP:           172.17.0.4
# Controlled By:  ReplicaSet/my-nginx-5b56ccd65f
# Containers:
#   my-nginx:
#     Container ID:   docker://3f53be8b44dfe15ab9e05ac9a2cfed41dbdb616b55b8db935701babd2110fb39
#     Image:          nginx
#     Image ID:       docker-pullable://nginx@sha256:10b8cc432d56da8b61b070f4c7d2543a9ed17c2b23010b43af434fd40e2ca4aa
#     Port:           80/TCP
#     Host Port:      0/TCP
#     State:          Running
#       Started:      Tue, 26 Jan 2021 09:39:19 +0000
#     Ready:          True
#     Restart Count:  0
#     Environment:    <none>
#     Mounts:
#       /var/run/secrets/kubernetes.io/serviceaccount from default-token-6582g (ro)
# Conditions:
#   Type              Status
#   Initialized       True
#   Ready             True
#   ContainersReady   True
#   PodScheduled      True
# Volumes:
#   default-token-6582g:
#     Type:        Secret (a volume populated by a Secret)
#     SecretName:  default-token-6582g
#     Optional:    false
# QoS Class:       BestEffort
# Node-Selectors:  <none>
# Tolerations:     node.kubernetes.io/not-ready:NoExecute op=Exists for 300s
#                  node.kubernetes.io/unreachable:NoExecute op=Exists for 300s
# Events:
#   Type    Reason     Age   From               Message
#   ----    ------     ----  ----               -------
#   Normal  Scheduled  50m   default-scheduler  Successfully assigned default/my-nginx-5b56ccd65f-8krqn to minikube
#   Normal  Pulling    50m   kubelet            Pulling image "nginx"
#   Normal  Pulled     50m   kubelet            Successfully pulled image "nginx" in 11.260302375s
#   Normal  Created    50m   kubelet            Created container my-nginx
#   Normal  Started    49m   kubelet            Started container my-nginx
#
#
# Name:         my-nginx-5b56ccd65f-s8qwn
# Namespace:    default
# Priority:     0
# Node:         minikube/192.168.49.2
# Start Time:   Tue, 26 Jan 2021 09:39:06 +0000
# Labels:       pod-template-hash=5b56ccd65f
#               run=my-nginx
# Annotations:  <none>
# Status:       Running
# IP:           172.17.0.3
# IPs:
#   IP:           172.17.0.3
# Controlled By:  ReplicaSet/my-nginx-5b56ccd65f
# Containers:
#   my-nginx:
#     Container ID:   docker://5da141e6ccb8b419d9eb18f89cc5f7656329f819e17c9d6fcbcc2edb0dc530f4
#     Image:          nginx
#     Image ID:       docker-pullable://nginx@sha256:10b8cc432d56da8b61b070f4c7d2543a9ed17c2b23010b43af434fd40e2ca4aa
#     Port:           80/TCP
#     Host Port:      0/TCP
#     State:          Running
#       Started:      Tue, 26 Jan 2021 09:39:21 +0000
#     Ready:          True
#     Restart Count:  0
#     Environment:    <none>
#     Mounts:
#       /var/run/secrets/kubernetes.io/serviceaccount from default-token-6582g (ro)
# Conditions:
#   Type              Status
#   Initialized       True
#   Ready             True
#   ContainersReady   True
#   PodScheduled      True
# Volumes:
#   default-token-6582g:
#     Type:        Secret (a volume populated by a Secret)
#     SecretName:  default-token-6582g
#     Optional:    false
# QoS Class:       BestEffort
# Node-Selectors:  <none>
# Tolerations:     node.kubernetes.io/not-ready:NoExecute op=Exists for 300s
#                  node.kubernetes.io/unreachable:NoExecute op=Exists for 300s
# Events:
#   Type    Reason     Age   From               Message
#   ----    ------     ----  ----               -------
#   Normal  Scheduled  50m   default-scheduler  Successfully assigned default/my-nginx-5b56ccd65f-s8qwn to minikube
#   Normal  Pulling    50m   kubelet            Pulling image "nginx"
#   Normal  Pulled     49m   kubelet            Successfully pulled image "nginx" in 12.645687297s
#   Normal  Created    49m   kubelet            Created container my-nginx
#   Normal  Started    49m   kubelet            Started container my-nginx

# %%
kubectl get pods -A -o jsonpath='{.items[*].metadata.name}'
# Out:
# my-nginx-5b56ccd65f-8krqn my-nginx-5b56ccd65f-s8qwn coredns-74ff55c5b-bx9lj etcd-minikube kube-apiserver-minikube kube-controller-manager-minikube kube-proxy-2rf67 kube-scheduler-minikube storage-provisioner dashboard-metrics-scraper-c95fcf479-zchqb kubernetes-dashboard-6cff4c7c4f-68nvz

# %% [markdown]
# More examples https://kubernetes.io/docs/reference/kubectl/jsonpath/

# %%
kubectl get pods -o json
# Out:
# {
#     "apiVersion": "v1",
#     "items": [
#         {
#             "apiVersion": "v1",
#             "kind": "Pod",
#             "metadata": {
#                 "creationTimestamp": "2021-01-26T09:39:06Z",
#                 "generateName": "my-nginx-5b56ccd65f-",
#                 "labels": {
#                     "pod-template-hash": "5b56ccd65f",
#                     "run": "my-nginx"
#                 },
#                 "managedFields": [
#                     {
#                         "apiVersion": "v1",
#                         "fieldsType": "FieldsV1",
#                         "fieldsV1": {
#                             "f:metadata": {
#                                 "f:generateName": {},
#                                 "f:labels": {
#                                     ".": {},
#                                     "f:pod-template-hash": {},
#                                     "f:run": {}
#                                 },
#                                 "f:ownerReferences": {
#                                     ".": {},
#                                     "k:{\"uid\":\"88acb46f-c470-41e8-b4a2-1c67a4e575e1\"}": {
#                                         ".": {},
#                                         "f:apiVersion": {},
#                                         "f:blockOwnerDeletion": {},
#                                         "f:controller": {},
#                                         "f:kind": {},
#                                         "f:name": {},
#                                         "f:uid": {}
#                                     }
#                                 }
#                             },
#                             "f:spec": {
#                                 "f:containers": {
#                                     "k:{\"name\":\"my-nginx\"}": {
#                                         ".": {},
#                                         "f:image": {},
#                                         "f:imagePullPolicy": {},
#                                         "f:name": {},
#                                         "f:ports": {
#                                             ".": {},
#                                             "k:{\"containerPort\":80,\"protocol\":\"TCP\"}": {
#                                                 ".": {},
#                                                 "f:containerPort": {},
#                                                 "f:protocol": {}
#                                             }
#                                         },
#                                         "f:resources": {},
#                                         "f:terminationMessagePath": {},
#                                         "f:terminationMessagePolicy": {}
#                                     }
#                                 },
#                                 "f:dnsPolicy": {},
#                                 "f:enableServiceLinks": {},
#                                 "f:restartPolicy": {},
#                                 "f:schedulerName": {},
#                                 "f:securityContext": {},
#                                 "f:terminationGracePeriodSeconds": {}
#                             }
#                         },
#                         "manager": "kube-controller-manager",
#                         "operation": "Update",
#                         "time": "2021-01-26T09:39:06Z"
#                     },
#                     {
#                         "apiVersion": "v1",
#                         "fieldsType": "FieldsV1",
#                         "fieldsV1": {
#                             "f:status": {
#                                 "f:conditions": {
#                                     "k:{\"type\":\"ContainersReady\"}": {
#                                         ".": {},
#                                         "f:lastProbeTime": {},
#                                         "f:lastTransitionTime": {},
#                                         "f:status": {},
#                                         "f:type": {}
#                                     },
#                                     "k:{\"type\":\"Initialized\"}": {
#                                         ".": {},
#                                         "f:lastProbeTime": {},
#                                         "f:lastTransitionTime": {},
#                                         "f:status": {},
#                                         "f:type": {}
#                                     },
#                                     "k:{\"type\":\"Ready\"}": {
#                                         ".": {},
#                                         "f:lastProbeTime": {},
#                                         "f:lastTransitionTime": {},
#                                         "f:status": {},
#                                         "f:type": {}
#                                     }
#                                 },
#                                 "f:containerStatuses": {},
#                                 "f:hostIP": {},
#                                 "f:phase": {},
#                                 "f:podIP": {},
#                                 "f:podIPs": {
#                                     ".": {},
#                                     "k:{\"ip\":\"172.17.0.4\"}": {
#                                         ".": {},
#                                         "f:ip": {}
#                                     }
#                                 },
#                                 "f:startTime": {}
#                             }
#                         },
#                         "manager": "kubelet",
#                         "operation": "Update",
#                         "time": "2021-01-26T09:39:20Z"
#                     }
#                 ],
#                 "name": "my-nginx-5b56ccd65f-8krqn",
#                 "namespace": "default",
#                 "ownerReferences": [
#                     {
#                         "apiVersion": "apps/v1",
#                         "blockOwnerDeletion": true,
#                         "controller": true,
#                         "kind": "ReplicaSet",
#                         "name": "my-nginx-5b56ccd65f",
#                         "uid": "88acb46f-c470-41e8-b4a2-1c67a4e575e1"
#                     }
#                 ],
#                 "resourceVersion": "3940",
#                 "uid": "7a69034a-66a1-49a2-9847-f74202b4a1cb"
#             },
#             "spec": {
#                 "containers": [
#                     {
#                         "image": "nginx",
#                         "imagePullPolicy": "Always",
#                         "name": "my-nginx",
#                         "ports": [
#                             {
#                                 "containerPort": 80,
#                                 "protocol": "TCP"
#                             }
#                         ],
#                         "resources": {},
#                         "terminationMessagePath": "/dev/termination-log",
#                         "terminationMessagePolicy": "File",
#                         "volumeMounts": [
#                             {
#                                 "mountPath": "/var/run/secrets/kubernetes.io/serviceaccount",
#                                 "name": "default-token-6582g",
#                                 "readOnly": true
#                             }
#                         ]
#                     }
#                 ],
#                 "dnsPolicy": "ClusterFirst",
#                 "enableServiceLinks": true,
#                 "nodeName": "minikube",
#                 "preemptionPolicy": "PreemptLowerPriority",
#                 "priority": 0,
#                 "restartPolicy": "Always",
#                 "schedulerName": "default-scheduler",
#                 "securityContext": {},
#                 "serviceAccount": "default",
#                 "serviceAccountName": "default",
#                 "terminationGracePeriodSeconds": 30,
#                 "tolerations": [
#                     {
#                         "effect": "NoExecute",
#                         "key": "node.kubernetes.io/not-ready",
#                         "operator": "Exists",
#                         "tolerationSeconds": 300
#                     },
#                     {
#                         "effect": "NoExecute",
#                         "key": "node.kubernetes.io/unreachable",
#                         "operator": "Exists",
#                         "tolerationSeconds": 300
#                     }
#                 ],
#                 "volumes": [
#                     {
#                         "name": "default-token-6582g",
#                         "secret": {
#                             "defaultMode": 420,
#                             "secretName": "default-token-6582g"
#                         }
#                     }
#                 ]
#             },
#             "status": {
#                 "conditions": [
#                     {
#                         "lastProbeTime": null,
#                         "lastTransitionTime": "2021-01-26T09:39:06Z",
#                         "status": "True",
#                         "type": "Initialized"
#                     },
#                     {
#                         "lastProbeTime": null,
#                         "lastTransitionTime": "2021-01-26T09:39:20Z",
#                         "status": "True",
#                         "type": "Ready"
#                     },
#                     {
#                         "lastProbeTime": null,
#                         "lastTransitionTime": "2021-01-26T09:39:20Z",
#                         "status": "True",
#                         "type": "ContainersReady"
#                     },
#                     {
#                         "lastProbeTime": null,
#                         "lastTransitionTime": "2021-01-26T09:39:06Z",
#                         "status": "True",
#                         "type": "PodScheduled"
#                     }
#                 ],
#                 "containerStatuses": [
#                     {
#                         "containerID": "docker://3f53be8b44dfe15ab9e05ac9a2cfed41dbdb616b55b8db935701babd2110fb39",
#                         "image": "nginx:latest",
#                         "imageID": "docker-pullable://nginx@sha256:10b8cc432d56da8b61b070f4c7d2543a9ed17c2b23010b43af434fd40e2ca4aa",
#                         "lastState": {},
#                         "name": "my-nginx",
#                         "ready": true,
#                         "restartCount": 0,
#                         "started": true,
#                         "state": {
#                             "running": {
#                                 "startedAt": "2021-01-26T09:39:19Z"
#                             }
#                         }
#                     }
#                 ],
#                 "hostIP": "192.168.49.2",
#                 "phase": "Running",
#                 "podIP": "172.17.0.4",
#                 "podIPs": [
#                     {
#                         "ip": "172.17.0.4"
#                     }
#                 ],
#                 "qosClass": "BestEffort",
#                 "startTime": "2021-01-26T09:39:06Z"
#             }
#         },
#         {
#             "apiVersion": "v1",
#             "kind": "Pod",
#             "metadata": {
#                 "creationTimestamp": "2021-01-26T09:39:06Z",
#                 "generateName": "my-nginx-5b56ccd65f-",
#                 "labels": {
#                     "pod-template-hash": "5b56ccd65f",
#                     "run": "my-nginx"
#                 },
#                 "managedFields": [
#                     {
#                         "apiVersion": "v1",
#                         "fieldsType": "FieldsV1",
#                         "fieldsV1": {
#                             "f:metadata": {
#                                 "f:generateName": {},
#                                 "f:labels": {
#                                     ".": {},
#                                     "f:pod-template-hash": {},
#                                     "f:run": {}
#                                 },
#                                 "f:ownerReferences": {
#                                     ".": {},
#                                     "k:{\"uid\":\"88acb46f-c470-41e8-b4a2-1c67a4e575e1\"}": {
#                                         ".": {},
#                                         "f:apiVersion": {},
#                                         "f:blockOwnerDeletion": {},
#                                         "f:controller": {},
#                                         "f:kind": {},
#                                         "f:name": {},
#                                         "f:uid": {}
#                                     }
#                                 }
#                             },
#                             "f:spec": {
#                                 "f:containers": {
#                                     "k:{\"name\":\"my-nginx\"}": {
#                                         ".": {},
#                                         "f:image": {},
#                                         "f:imagePullPolicy": {},
#                                         "f:name": {},
#                                         "f:ports": {
#                                             ".": {},
#                                             "k:{\"containerPort\":80,\"protocol\":\"TCP\"}": {
#                                                 ".": {},
#                                                 "f:containerPort": {},
#                                                 "f:protocol": {}
#                                             }
#                                         },
#                                         "f:resources": {},
#                                         "f:terminationMessagePath": {},
#                                         "f:terminationMessagePolicy": {}
#                                     }
#                                 },
#                                 "f:dnsPolicy": {},
#                                 "f:enableServiceLinks": {},
#                                 "f:restartPolicy": {},
#                                 "f:schedulerName": {},
#                                 "f:securityContext": {},
#                                 "f:terminationGracePeriodSeconds": {}
#                             }
#                         },
#                         "manager": "kube-controller-manager",
#                         "operation": "Update",
#                         "time": "2021-01-26T09:39:06Z"
#                     },
#                     {
#                         "apiVersion": "v1",
#                         "fieldsType": "FieldsV1",
#                         "fieldsV1": {
#                             "f:status": {
#                                 "f:conditions": {
#                                     "k:{\"type\":\"ContainersReady\"}": {
#                                         ".": {},
#                                         "f:lastProbeTime": {},
#                                         "f:lastTransitionTime": {},
#                                         "f:status": {},
#                                         "f:type": {}
#                                     },
#                                     "k:{\"type\":\"Initialized\"}": {
#                                         ".": {},
#                                         "f:lastProbeTime": {},
#                                         "f:lastTransitionTime": {},
#                                         "f:status": {},
#                                         "f:type": {}
#                                     },
#                                     "k:{\"type\":\"Ready\"}": {
#                                         ".": {},
#                                         "f:lastProbeTime": {},
#                                         "f:lastTransitionTime": {},
#                                         "f:status": {},
#                                         "f:type": {}
#                                     }
#                                 },
#                                 "f:containerStatuses": {},
#                                 "f:hostIP": {},
#                                 "f:phase": {},
#                                 "f:podIP": {},
#                                 "f:podIPs": {
#                                     ".": {},
#                                     "k:{\"ip\":\"172.17.0.3\"}": {
#                                         ".": {},
#                                         "f:ip": {}
#                                     }
#                                 },
#                                 "f:startTime": {}
#                             }
#                         },
#                         "manager": "kubelet",
#                         "operation": "Update",
#                         "time": "2021-01-26T09:39:21Z"
#                     }
#                 ],
#                 "name": "my-nginx-5b56ccd65f-s8qwn",
#                 "namespace": "default",
#                 "ownerReferences": [
#                     {
#                         "apiVersion": "apps/v1",
#                         "blockOwnerDeletion": true,
#                         "controller": true,
#                         "kind": "ReplicaSet",
#                         "name": "my-nginx-5b56ccd65f",
#                         "uid": "88acb46f-c470-41e8-b4a2-1c67a4e575e1"
#                     }
#                 ],
#                 "resourceVersion": "3948",
#                 "uid": "af41adda-6f71-4e0e-9ed3-2b066c044bf7"
#             },
#             "spec": {
#                 "containers": [
#                     {
#                         "image": "nginx",
#                         "imagePullPolicy": "Always",
#                         "name": "my-nginx",
#                         "ports": [
#                             {
#                                 "containerPort": 80,
#                                 "protocol": "TCP"
#                             }
#                         ],
#                         "resources": {},
#                         "terminationMessagePath": "/dev/termination-log",
#                         "terminationMessagePolicy": "File",
#                         "volumeMounts": [
#                             {
#                                 "mountPath": "/var/run/secrets/kubernetes.io/serviceaccount",
#                                 "name": "default-token-6582g",
#                                 "readOnly": true
#                             }
#                         ]
#                     }
#                 ],
#                 "dnsPolicy": "ClusterFirst",
#                 "enableServiceLinks": true,
#                 "nodeName": "minikube",
#                 "preemptionPolicy": "PreemptLowerPriority",
#                 "priority": 0,
#                 "restartPolicy": "Always",
#                 "schedulerName": "default-scheduler",
#                 "securityContext": {},
#                 "serviceAccount": "default",
#                 "serviceAccountName": "default",
#                 "terminationGracePeriodSeconds": 30,
#                 "tolerations": [
#                     {
#                         "effect": "NoExecute",
#                         "key": "node.kubernetes.io/not-ready",
#                         "operator": "Exists",
#                         "tolerationSeconds": 300
#                     },
#                     {
#                         "effect": "NoExecute",
#                         "key": "node.kubernetes.io/unreachable",
#                         "operator": "Exists",
#                         "tolerationSeconds": 300
#                     }
#                 ],
#                 "volumes": [
#                     {
#                         "name": "default-token-6582g",
#                         "secret": {
#                             "defaultMode": 420,
#                             "secretName": "default-token-6582g"
#                         }
#                     }
#                 ]
#             },
#             "status": {
#                 "conditions": [
#                     {
#                         "lastProbeTime": null,
#                         "lastTransitionTime": "2021-01-26T09:39:06Z",
#                         "status": "True",
#                         "type": "Initialized"
#                     },
#                     {
#                         "lastProbeTime": null,
#                         "lastTransitionTime": "2021-01-26T09:39:21Z",
#                         "status": "True",
#                         "type": "Ready"
#                     },
#                     {
#                         "lastProbeTime": null,
#                         "lastTransitionTime": "2021-01-26T09:39:21Z",
#                         "status": "True",
#                         "type": "ContainersReady"
#                     },
#                     {
#                         "lastProbeTime": null,
#                         "lastTransitionTime": "2021-01-26T09:39:06Z",
#                         "status": "True",
#                         "type": "PodScheduled"
#                     }
#                 ],
#                 "containerStatuses": [
#                     {
#                         "containerID": "docker://5da141e6ccb8b419d9eb18f89cc5f7656329f819e17c9d6fcbcc2edb0dc530f4",
#                         "image": "nginx:latest",
#                         "imageID": "docker-pullable://nginx@sha256:10b8cc432d56da8b61b070f4c7d2543a9ed17c2b23010b43af434fd40e2ca4aa",
#                         "lastState": {},
#                         "name": "my-nginx",
#                         "ready": true,
#                         "restartCount": 0,
#                         "started": true,
#                         "state": {
#                             "running": {
#                                 "startedAt": "2021-01-26T09:39:21Z"
#                             }
#                         }
#                     }
#                 ],
#                 "hostIP": "192.168.49.2",
#                 "phase": "Running",
#                 "podIP": "172.17.0.3",
#                 "podIPs": [
#                     {
#                         "ip": "172.17.0.3"
#                     }
#                 ],
#                 "qosClass": "BestEffort",
#                 "startTime": "2021-01-26T09:39:06Z"
#             }
#         }
#     ],
#     "kind": "List",
#     "metadata": {
#         "resourceVersion": "",
#         "selfLink": ""
#     }
# }

# %%
kubectl get pods -o=jsonpath='{@}'
# Out:
# {"apiVersion":"v1","items":[{"apiVersion":"v1","kind":"Pod","metadata":{"creationTimestamp":"2021-01-26T09:39:06Z","generateName":"my-nginx-5b56ccd65f-","labels":{"pod-template-hash":"5b56ccd65f","run":"my-nginx"},"managedFields":[{"apiVersion":"v1","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":{"f:generateName":{},"f:labels":{".":{},"f:pod-template-hash":{},"f:run":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"88acb46f-c470-41e8-b4a2-1c67a4e575e1\"}":{".":{},"f:apiVersion":{},"f:blockOwnerDeletion":{},"f:controller":{},"f:kind":{},"f:name":{},"f:uid":{}}}},"f:spec":{"f:containers":{"k:{\"name\":\"my-nginx\"}":{".":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":80,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:protocol":{}}},"f:resources":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:terminationGracePeriodSeconds":{}}},"manager":"kube-controller-manager","operation":"Update","time":"2021-01-26T09:39:06Z"},{"apiVersion":"v1","fieldsType":"FieldsV1","fieldsV1":{"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"172.17.0.4\"}":{".":{},"f:ip":{}}},"f:startTime":{}}},"manager":"kubelet","operation":"Update","time":"2021-01-26T09:39:20Z"}],"name":"my-nginx-5b56ccd65f-8krqn","namespace":"default","ownerReferences":[{"apiVersion":"apps/v1","blockOwnerDeletion":true,"controller":true,"kind":"ReplicaSet","name":"my-nginx-5b56ccd65f","uid":"88acb46f-c470-41e8-b4a2-1c67a4e575e1"}],"resourceVersion":"3940","uid":"7a69034a-66a1-49a2-9847-f74202b4a1cb"},"spec":{"containers":[{"image":"nginx","imagePullPolicy":"Always","name":"my-nginx","ports":[{"containerPort":80,"protocol":"TCP"}],"resources":{},"terminationMessagePath":"/dev/termination-log","terminationMessagePolicy":"File","volumeMounts":[{"mountPath":"/var/run/secrets/kubernetes.io/serviceaccount","name":"default-token-6582g","readOnly":true}]}],"dnsPolicy":"ClusterFirst","enableServiceLinks":true,"nodeName":"minikube","preemptionPolicy":"PreemptLowerPriority","priority":0,"restartPolicy":"Always","schedulerName":"default-scheduler","securityContext":{},"serviceAccount":"default","serviceAccountName":"default","terminationGracePeriodSeconds":30,"tolerations":[{"effect":"NoExecute","key":"node.kubernetes.io/not-ready","operator":"Exists","tolerationSeconds":300},{"effect":"NoExecute","key":"node.kubernetes.io/unreachable","operator":"Exists","tolerationSeconds":300}],"volumes":[{"name":"default-token-6582g","secret":{"defaultMode":420,"secretName":"default-token-6582g"}}]},"status":{"conditions":[{"lastProbeTime":null,"lastTransitionTime":"2021-01-26T09:39:06Z","status":"True","type":"Initialized"},{"lastProbeTime":null,"lastTransitionTime":"2021-01-26T09:39:20Z","status":"True","type":"Ready"},{"lastProbeTime":null,"lastTransitionTime":"2021-01-26T09:39:20Z","status":"True","type":"ContainersReady"},{"lastProbeTime":null,"lastTransitionTime":"2021-01-26T09:39:06Z","status":"True","type":"PodScheduled"}],"containerStatuses":[{"containerID":"docker://3f53be8b44dfe15ab9e05ac9a2cfed41dbdb616b55b8db935701babd2110fb39","image":"nginx:latest","imageID":"docker-pullable://nginx@sha256:10b8cc432d56da8b61b070f4c7d2543a9ed17c2b23010b43af434fd40e2ca4aa","lastState":{},"name":"my-nginx","ready":true,"restartCount":0,"started":true,"state":{"running":{"startedAt":"2021-01-26T09:39:19Z"}}}],"hostIP":"192.168.49.2","phase":"Running","podIP":"172.17.0.4","podIPs":[{"ip":"172.17.0.4"}],"qosClass":"BestEffort","start ...

# %%
kubectl get pods -o=jsonpath='{.items[0]}'
# Out:
# {"apiVersion":"v1","kind":"Pod","metadata":{"creationTimestamp":"2021-01-26T09:39:06Z","generateName":"my-nginx-5b56ccd65f-","labels":{"pod-template-hash":"5b56ccd65f","run":"my-nginx"},"managedFields":[{"apiVersion":"v1","fieldsType":"FieldsV1","fieldsV1":{"f:metadata":{"f:generateName":{},"f:labels":{".":{},"f:pod-template-hash":{},"f:run":{}},"f:ownerReferences":{".":{},"k:{\"uid\":\"88acb46f-c470-41e8-b4a2-1c67a4e575e1\"}":{".":{},"f:apiVersion":{},"f:blockOwnerDeletion":{},"f:controller":{},"f:kind":{},"f:name":{},"f:uid":{}}}},"f:spec":{"f:containers":{"k:{\"name\":\"my-nginx\"}":{".":{},"f:image":{},"f:imagePullPolicy":{},"f:name":{},"f:ports":{".":{},"k:{\"containerPort\":80,\"protocol\":\"TCP\"}":{".":{},"f:containerPort":{},"f:protocol":{}}},"f:resources":{},"f:terminationMessagePath":{},"f:terminationMessagePolicy":{}}},"f:dnsPolicy":{},"f:enableServiceLinks":{},"f:restartPolicy":{},"f:schedulerName":{},"f:securityContext":{},"f:terminationGracePeriodSeconds":{}}},"manager":"kube-controller-manager","operation":"Update","time":"2021-01-26T09:39:06Z"},{"apiVersion":"v1","fieldsType":"FieldsV1","fieldsV1":{"f:status":{"f:conditions":{"k:{\"type\":\"ContainersReady\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Initialized\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}},"k:{\"type\":\"Ready\"}":{".":{},"f:lastProbeTime":{},"f:lastTransitionTime":{},"f:status":{},"f:type":{}}},"f:containerStatuses":{},"f:hostIP":{},"f:phase":{},"f:podIP":{},"f:podIPs":{".":{},"k:{\"ip\":\"172.17.0.4\"}":{".":{},"f:ip":{}}},"f:startTime":{}}},"manager":"kubelet","operation":"Update","time":"2021-01-26T09:39:20Z"}],"name":"my-nginx-5b56ccd65f-8krqn","namespace":"default","ownerReferences":[{"apiVersion":"apps/v1","blockOwnerDeletion":true,"controller":true,"kind":"ReplicaSet","name":"my-nginx-5b56ccd65f","uid":"88acb46f-c470-41e8-b4a2-1c67a4e575e1"}],"resourceVersion":"3940","uid":"7a69034a-66a1-49a2-9847-f74202b4a1cb"},"spec":{"containers":[{"image":"nginx","imagePullPolicy":"Always","name":"my-nginx","ports":[{"containerPort":80,"protocol":"TCP"}],"resources":{},"terminationMessagePath":"/dev/termination-log","terminationMessagePolicy":"File","volumeMounts":[{"mountPath":"/var/run/secrets/kubernetes.io/serviceaccount","name":"default-token-6582g","readOnly":true}]}],"dnsPolicy":"ClusterFirst","enableServiceLinks":true,"nodeName":"minikube","preemptionPolicy":"PreemptLowerPriority","priority":0,"restartPolicy":"Always","schedulerName":"default-scheduler","securityContext":{},"serviceAccount":"default","serviceAccountName":"default","terminationGracePeriodSeconds":30,"tolerations":[{"effect":"NoExecute","key":"node.kubernetes.io/not-ready","operator":"Exists","tolerationSeconds":300},{"effect":"NoExecute","key":"node.kubernetes.io/unreachable","operator":"Exists","tolerationSeconds":300}],"volumes":[{"name":"default-token-6582g","secret":{"defaultMode":420,"secretName":"default-token-6582g"}}]},"status":{"conditions":[{"lastProbeTime":null,"lastTransitionTime":"2021-01-26T09:39:06Z","status":"True","type":"Initialized"},{"lastProbeTime":null,"lastTransitionTime":"2021-01-26T09:39:20Z","status":"True","type":"Ready"},{"lastProbeTime":null,"lastTransitionTime":"2021-01-26T09:39:20Z","status":"True","type":"ContainersReady"},{"lastProbeTime":null,"lastTransitionTime":"2021-01-26T09:39:06Z","status":"True","type":"PodScheduled"}],"containerStatuses":[{"containerID":"docker://3f53be8b44dfe15ab9e05ac9a2cfed41dbdb616b55b8db935701babd2110fb39","image":"nginx:latest","imageID":"docker-pullable://nginx@sha256:10b8cc432d56da8b61b070f4c7d2543a9ed17c2b23010b43af434fd40e2ca4aa","lastState":{},"name":"my-nginx","ready":true,"restartCount":0,"started":true,"state":{"running":{"startedAt":"2021-01-26T09:39:19Z"}}}],"hostIP":"192.168.49.2","phase":"Running","podIP":"172.17.0.4","podIPs":[{"ip":"172.17.0.4"}],"qosClass":"BestEffort","startTime":"2021-01-26T09:39:06Z" ...

# %%
kubectl get pods -o=jsonpath='{.items[0].metadata.name}'
# Out:
# my-nginx-5b56ccd65f-8krqn

# %%
kubectl get pods -o=jsonpath="{.items[*]['metadata.name', 'status.capacity']}"
# Out:
# my-nginx-5b56ccd65f-6fjrm my-nginx-5b56ccd65f-k5drn

# %%
kubectl get pods -o=jsonpath='{range .items[*]}{.metadata.name}{"\t"}{.status.startTime}{"\n"}{end}'
# Out:
# my-nginx-5b56ccd65f-8krqn	2021-01-26T09:39:06Z
# my-nginx-5b56ccd65f-s8qwn	2021-01-26T09:39:06Z

# %% [markdown]
# List all images
#
# https://kubernetes.io/docs/tasks/access-application-cluster/list-all-running-container-images/

# %%
kubectl get pods --all-namespaces -o go-template \
--template="{{range .items}}{{.metadata.namespace}}/{{.metadata.name}}:{{println}}{{range .spec.containers}}  {{.image}}:{{.securityContext}}
{{end}}{{end}}"
# Out:
# default/my-nginx-5b56ccd65f-8krqn:
#   nginx:<no value>
# default/my-nginx-5b56ccd65f-s8qwn:
#   nginx:<no value>
# kube-system/coredns-74ff55c5b-bx9lj:
#   k8s.gcr.io/coredns:1.7.0:map[allowPrivilegeEscalation:false capabilities:map[add:[NET_BIND_SERVICE] drop:[all]] readOnlyRootFilesystem:true]
# kube-system/etcd-minikube:
#   k8s.gcr.io/etcd:3.4.13-0:<no value>
# kube-system/kube-apiserver-minikube:
#   k8s.gcr.io/kube-apiserver:v1.20.0:<no value>
# kube-system/kube-controller-manager-minikube:
#   k8s.gcr.io/kube-controller-manager:v1.20.0:<no value>
# kube-system/kube-proxy-2rf67:
#   k8s.gcr.io/kube-proxy:v1.20.0:map[privileged:true]
# kube-system/kube-scheduler-minikube:
#   k8s.gcr.io/kube-scheduler:v1.20.0:<no value>
# kube-system/storage-provisioner:
#   gcr.io/k8s-minikube/storage-provisioner:v4:<no value>
# kubernetes-dashboard/dashboard-metrics-scraper-c95fcf479-zchqb:
#   kubernetesui/metrics-scraper:v1.0.4:map[allowPrivilegeEscalation:false readOnlyRootFilesystem:true runAsGroup:2001 runAsUser:1001]
# kubernetes-dashboard/kubernetes-dashboard-6cff4c7c4f-68nvz:
#   kubernetesui/dashboard:v2.1.0:map[allowPrivilegeEscalation:false readOnlyRootFilesystem:true runAsGroup:2001 runAsUser:1001]

# %%
kubectl get pods --all-namespaces -o go-template \
--template="{{range .items}}{{.metadata.namespace}}/{{.metadata.name}}:{{println}}{{range .spec.initContainers}}  {{.image}}:{{.securityContext}}
{{end}}{{end}}"
# Out:
# default/my-nginx-5b56ccd65f-8krqn:
# default/my-nginx-5b56ccd65f-s8qwn:
# kube-system/coredns-74ff55c5b-bx9lj:
# kube-system/etcd-minikube:
# kube-system/kube-apiserver-minikube:
# kube-system/kube-controller-manager-minikube:
# kube-system/kube-proxy-2rf67:
# kube-system/kube-scheduler-minikube:
# kube-system/storage-provisioner:
# kubernetes-dashboard/dashboard-metrics-scraper-c95fcf479-zchqb:
# kubernetes-dashboard/kubernetes-dashboard-6cff4c7c4f-68nvz:
