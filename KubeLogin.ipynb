# %% [markdown]
# **This notebook covered by the following [license](License.ipynb)  This note must not be removed**

# %% [markdown]
# # Install kubelogin
#
# This is a kubectl plugin for Kubernetes OpenID Connect (OIDC) authentication, also known as kubectl oidc-login.
#
# https://github.com/int128/kubelogin
#
# https://github.com/int128/kubelogin/blob/master/docs/credential-plugin-diagram.svg

# %%
go install -v github.com/int128/kubelogin@latest
# Out:
# go: downloading github.com/int128/kubelogin v1.25.0
# go: downloading k8s.io/client-go v0.22.1
# go: downloading github.com/pkg/browser v0.0.0-20210904010418-6d279e18f982
# go: downloading k8s.io/apimachinery v0.22.1
# go: downloading golang.org/x/term v0.0.0-20210615171337-6886f2dfbf5b
# go: downloading github.com/alexflint/go-filemutex v1.1.0
# go: downloading github.com/int128/oauth2cli v1.13.0
# go: downloading golang.org/x/oauth2 v0.0.0-20210819190943-2bc19b11175f
# go: downloading k8s.io/klog/v2 v2.20.0
# go: downloading github.com/go-logr/logr v1.0.0
# go: downloading golang.org/x/net v0.0.0-20210903162142-ad29c8ab022f
# go: downloading github.com/int128/listener v1.1.0
# github.com/google/wire
# github.com/int128/kubelogin/pkg/kubeconfig
# golang.org/x/sys/internal/unsafeheader
# k8s.io/apimachinery/pkg/selection
# github.com/google/go-cmp/cmp/internal/flags
# k8s.io/apimachinery/pkg/types
# github.com/int128/kubelogin/pkg/tokencache
# k8s.io/utils/integer
# ...

# %%
which kubelogin
# Out:
# /home/thomas/go/bin/kubelogin
